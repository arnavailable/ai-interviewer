# %%
ANTHROPIC_API_KEY = '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'
GOOGLE_API_KEY = 'AIzaSyBsBhlVsf9OJl1-4_yofzk8bdziDagIZao'

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Obtaining dependency information for pyttsx3 from https://files.pythonhosted.org/packages/33/9a/de4781245f5ad966646fd276259ef7cfd400ba3cf7d5db7c0d5aab310c20/pyttsx3-2.90-py3-none-any.whl.metadata
#   Downloading pyttsx3-2.90-py3-none-any.whl.metadata (3.6 kB)
# Collecting pyobjc>=2.4 (from pyttsx3)
#   Obtaining dependency information for pyobjc>=2.4 from https://files.pythonhosted.org/packages/cb/a5/4b9ed66894d804dc57c13b7fdb8f65ed831f13514216ce736e1455dfe214/pyobjc-10.3.1-py3-none-any.whl.metadata
#   Downloading pyobjc-10.3.1-py3-none-any.whl.metadata (26 kB)
# Collecting pyobjc-core==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-core==10.3.1 from https://files.pythonhosted.org/packages/ba/69/e782f176bb5ac71473563f4e5cf825c48b1d7d1fbe1fadde201027804e45/pyobjc_core-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading pyobjc_core-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AddressBook==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-AddressBook==10.3.1 from https://files.pythonhosted.org/packages/c0/b2/730fe2665b385fe5ad59fee25d562ed182f3369885d467aafcb369fb9c63/pyobjc_framework_AddressBook-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Downloading pyobjc_framework_AddressBook-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AppleScriptKit==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-AppleScriptKit==10.3.1 from https://files.pythonhosted.org/packages/0c/0b/6638a036e5e4b8451d9c5e96da5ec1bfcf4bee68b09b2e28158445d767e4/pyobjc_framework_AppleScriptKit-10.3.1-py2.py3-none-any.whl.metadata
#   Downloading pyobjc_framework_AppleScriptKit-10.3.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ApplicationServices==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-ApplicationServices==10.3.1 from https://files.pythonhosted.org/packages/78/24/31fdd15f88d3a0a88ba88b27d1f134c7819221886bf56644af12fe672c6d/pyobjc_framework_ApplicationServices-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading pyobjc_framework_ApplicationServices-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-Automator==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-Automator==10.3.1 from https://files.pythonhosted.org/packages/00/0c/4c81e55eb886112756177f86389558ee0b04ec060b4eaca122e4f83f8bdc/pyobjc_framework_Automator-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Downloading pyobjc_framework_Automator-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CFNetwork==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-CFNetwork==10.3.1 from https://files.pythonhosted.org/packages/e7/2d/bc2e628e12d0bd7e287ed8f7af3b0df347d1814d950a566fe3cd48e01480/pyobjc_framework_CFNetwork-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Downloading pyobjc_framework_CFNetwork-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Cocoa==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-Cocoa==10.3.1 from https://files.pythonhosted.org/packages/d4/ad/436c3619d1a84f83d55ff9c709b122e4d1ac2ee9af467b68fcb60e5ad3a6/pyobjc_framework_Cocoa-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading pyobjc_framework_Cocoa-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreAudio==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-CoreAudio==10.3.1 from https://files.pythonhosted.org/packages/6f/dd/e4be148694e5e73885aaf00a92720293674fd510d87369cf5ba300f24660/pyobjc_framework_CoreAudio-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading pyobjc_framework_CoreAudio-10.3.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreAudioKit==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-CoreAudioKit==10.3.1 from https://files.pythonhosted.org/packages/43/df/910252ab44c47e48421f57be17c539e2f828653834cfbc7343e9f379db4e/pyobjc_framework_CoreAudioKit-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Downloading pyobjc_framework_Co
10.3.1-py2.py3-none-any.whl.metadata
#   Downloading pyobjc_framework_FileProviderUI-10.3.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-LinkPresentation==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-LinkPresentation==10.3.1 from https://files.pythonhosted.org/packages/a4/6a/6347826cc12c01bfd2f6c804af1d99d4df8cd74440a412562b72cbbd97f5/pyobjc_framework_LinkPresentation-10.3.1-py2.py3-none-any.whl.metadata
#   Downloading pyobjc_framework_LinkPresentation-10.3.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-OSLog==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-OSLog==10.3.1 from https://files.pythonhosted.org/packages/fe/33/8185fa32c8705f1b16b0d91b62ab290159d7611f2cf46db0fea7c8c87703/pyobjc_framework_OSLog-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Downloading pyobjc_framework_OSLog-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-PencilKit==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-PencilKit==10.3.1 from https://files.pythonhosted.org/packages/1b/41/a15fd222e8f9b28ab18440ac3d4c2aca98c640f2e1456dbc018c451c7556/pyobjc_framework_PencilKit-10.3.1-py2.py3-none-any.whl.metadata
#   Downloading pyobjc_framework_PencilKit-10.3.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-PushKit==10.3.1 (from pyobjc>=2.4->pyttsx3)
#   Obtaining dependency information for pyobjc-framework-PushKit==10.3.1 from https://files.pythonhosted.org/packages/21/ab/c15351016775f0134b3d500f599d07fb20fffae7ec85c089e1ee79f047c9/pyobjc_framework_PushKit-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata
#   Downloading pyobjc_framework_PushKit-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==10.3.1 (from pyobjc>=2.4->pyttsx3)
# ...
# Downloading pyobjc_framework_LaunchServices-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Downloading pyobjc_framework_libdispatch-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (20 kB)
# Downloading pyobjc_framework_libxpc-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (19 kB)
# Downloading pyobjc_framework_LinkPresentation-10.3.1-py2.py3-none-any.whl (3.5 kB)
# Downloading pyobjc_framework_LocalAuthentication-10.3.1-py2.py3-none-any.whl (5.7 kB)
# Downloading pyobjc_framework_LocalAuthenticationEmbeddedUI-10.3.1-py2.py3-none-any.whl (3.6 kB)
# Downloading pyobjc_framework_MailKit-10.3.1-py2.py3-none-any.whl (4.5 kB)
# Downloading pyobjc_framework_MapKit-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (22 kB)
# Downloading pyobjc_framework_MediaAccessibility-10.3.1-py2.py3-none-any.whl (4.1 kB)
# Downloading pyobjc_framework_MediaLibrary-10.3.1-py2.py3-none-any.whl (4.0 kB)
# Downloading pyobjc_framework_MediaPlayer-10.3.1-py2.py3-none-any.whl (6.5 kB)
# Downloading pyobjc_framework_MediaToolbox-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (13 kB)
# Downloading pyobjc_framework_Metal-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.5 MB/s eta 0:00:00
# Downloading pyobjc_framework_MetalFX-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (10 kB)
# Downloading pyobjc_framework_MetalKit-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (9.1 kB)
# Downloading pyobjc_framework_MetalPerformanceShaders-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (33 kB)
# Downloading pyobjc_framework_MetalPerformanceShadersGraph-10.3.1-py2.py3-none-any.whl (6.0 kB)
# Downloading pyobjc_framework_MetricKit-10.3.1-cp311-cp311-macosx_10_9_universal2.whl (8.2 kB)
# Downloading pyobjc_framework_MLCompute-10.3.1-py2.py3-none-any.whl (6.4 kB)
# Downloading pyobjc_framework_ModelIO-10.3.1-cp36-abi3-macosx_11_0_universal2.whl (21 kB)
# Downloading pyobjc_framework_MultipeerConnectivity-10.3.1-cp36-abi3-macosx_11_0_universal2.whl
pyobjc-framework-ExceptionHandling, pyobjc-framework-EventKit, pyobjc-framework-DVDPlayback, pyobjc-framework-DiskArbitration, pyobjc-framework-DiscRecording, pyobjc-framework-DeviceCheck, pyobjc-framework-DataDetection, pyobjc-framework-CryptoTokenKit, pyobjc-framework-CoreWLAN, pyobjc-framework-CoreSpotlight, pyobjc-framework-CoreMotion, pyobjc-framework-CoreML, pyobjc-framework-CoreMIDI, pyobjc-framework-CoreMediaIO, pyobjc-framework-CoreMedia, pyobjc-framework-CoreLocation, pyobjc-framework-CoreHaptics, pyobjc-framework-CoreData, pyobjc-framework-CoreBluetooth, pyobjc-framework-CoreAudio, pyobjc-framework-Contacts, pyobjc-framework-ColorSync, pyobjc-framework-Collaboration, pyobjc-framework-ClassKit, pyobjc-framework-CFNetwork, pyobjc-framework-CallKit, pyobjc-framework-CalendarStore, pyobjc-framework-BusinessChat, pyobjc-framework-BackgroundAssets, pyobjc-framework-AVRouting, pyobjc-framework-Automator, pyobjc-framework-AutomaticAssessmentConfiguration, pyobjc-framework-AuthenticationServices, pyobjc-framework-AudioVideoBridging, pyobjc-framework-AppTrackingTransparency, pyobjc-framework-AppleScriptObjC, pyobjc-framework-AppleScriptKit, pyobjc-framework-AdSupport, pyobjc-framework-AdServices, pyobjc-framework-AddressBook, pyobjc-framework-Accounts, pyobjc-framework-Vision, pyobjc-framework-VideoToolbox, pyobjc-framework-UserNotificationsUI, pyobjc-framework-SyncServices, pyobjc-framework-SpriteKit, pyobjc-framework-SharedWithYou, pyobjc-framework-SensitiveContentAnalysis, pyobjc-framework-SecurityInterface, pyobjc-framework-SecurityFoundation, pyobjc-framework-ScreenCaptureKit, pyobjc-framework-SceneKit, pyobjc-framework-SafetyKit, pyobjc-framework-QuickLookThumbnailing, pyobjc-framework-OSLog, pyobjc-framework-ModelIO, pyobjc-framework-MetalPerformanceShaders, pyobjc-framework-MetalKit, pyobjc-framework-MetalFX, pyobjc-framework-MediaLibrary, pyobjc-framework-MapKit, pyobjc-framework-LocalAuthentication, pyobjc-framework-LinkPresentation, pyobjc-fram ...
#   Attempting uninstall: pyobjc-core
#     Found existing installation: pyobjc-core 9.0
#     Uninstalling pyobjc-core-9.0:
#       Successfully uninstalled pyobjc-core-9.0
#   Attempting uninstall: pyobjc-framework-Cocoa
#     Found existing installation: pyobjc-framework-Cocoa 9.0
#     Uninstalling pyobjc-framework-Cocoa-9.0:
#       Successfully uninstalled pyobjc-framework-Cocoa-9.0
#   Attempting uninstall: pyobjc-framework-FSEvents
#     Found existing installation: pyobjc-framework-FSEvents 9.0
#     Uninstalling pyobjc-framework-FSEvents-9.0:
#       Successfully uninstalled pyobjc-framework-FSEvents-9.0
#   Attempting uninstall: pyobjc-framework-CoreServices
#     Found existing installation: pyobjc-framework-CoreServices 9.0
#     Uninstalling pyobjc-framework-CoreServices-9.0:
#       Successfully uninstalled pyobjc-framework-CoreServices-9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5
cp36-abi3-macosx_11_0_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SoundAnalysis==9.0.1 (from pyobjc==9.0.1->py3-tts)
# ...
#     Uninstalling pyobjc-framework-ScreenCaptureKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-ScreenCaptureKit-10.3.1
#   Attempting uninstall: pyobjc-framework-SceneKit
#     Found existing installation: pyobjc-framework-SceneKit 10.3.1
#     Uninstalling pyobjc-framework-SceneKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-SceneKit-10.3.1
#   Attempting uninstall: pyobjc-framework-SafetyKit
#     Found existing installation: pyobjc-framework-SafetyKit 10.3.1
#     Uninstalling pyobjc-framework-SafetyKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-SafetyKit-10.3.1
#   Attempting uninstall: pyobjc-framework-QuickLookThumbnailing
#     Found existing installation: pyobjc-framework-QuickLookThumbnailing 10.3.1
#     Uninstalling pyobjc-framework-QuickLookThumbnailing-10.3.1:
#       Successfully uninstalled pyobjc-framework-QuickLookThumbnailing-10.3.1
#   Attempting uninstall: pyobjc-framework-OSLog
#     Found existing installation: pyobjc-framework-OSLog 10.3.1
#     Uninstalling pyobjc-framework-OSLog-10.3.1:
#       Successfully uninstalled pyobjc-framework-OSLog-10.3.1
#   Attempting uninstall: pyobjc-framework-ModelIO
#     Found existing installation: pyobjc-framework-ModelIO 10.3.1
#     Uninstalling pyobjc-framework-ModelIO-10.3.1:
#       Successfully uninstalled pyobjc-framework-ModelIO-10.3.1
#   Attempting uninstall: pyobjc-framework-MetalPerformanceShaders
#     Found existing installation: pyobjc-framework-MetalPerformanceShaders 10.3.1
#     Uninstalling pyobjc-framework-MetalPerformanceShaders-10.3.1:
#       Successfully uninstalled pyobjc-framework-MetalPerformanceShaders-10.3.1
#   Attempting uninstall: pyobjc-framework-MetalKit
#     Found existing installation: pyobjc-framework-MetalKit 10.3.1
#     Uninstalling pyobjc-framework-MetalKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-MetalKit-10.3.1
#   Attempting uninstall: pyobjc-framework-MetalFX
#     Found existing installation: pyobjc-framework-MetalFX 10.3.1
#     Uninstalling pyobjc-framework-MetalFX-10.3.1:
#       Successfully uninstalled pyobjc-framework-MetalFX-10.3.1
#   Attempting uninstall: pyobjc-framework-MediaLibrary
#     Found existing installation: pyobjc-framework-MediaLibrary 10.3.1
#     Uninstalling pyobjc-framework-MediaLibrary-10.3.1:
#       Successfully uninstalled pyobjc-framework-MediaLibrary-10.3.1
#   Attempting uninstall: pyobjc-framework-MapKit
#     Found existing installation: pyobjc-framework-MapKit 10.3.1
#     Uninstalling pyobjc-framework-MapKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-MapKit-10.3.1
#   Attempting uninstall: pyobjc-framework-LocalAuthentication
#     Found existing installation: pyobjc-framework-LocalAuthentication 10.3.1
#     Uninstalling pyobjc-framework-LocalAuthentication-10.3.1:
#       Successfully uninstalled pyobjc-framework-LocalAuthentication-10.3.1
#   Attempting uninstall: pyobjc-framework-LinkPresentation
#     Found existing installation: pyobjc-framework-LinkPresentation 10.3.1
#     Uninstalling pyobjc-framework-LinkPresentation-10.3.1:
#       Successfully uninstalled pyobjc-framework-LinkPresentation-10.3.1
#   Attempting uninstall: pyobjc-framework-IntentsUI
#     Found existing installation: pyobjc-framework-IntentsUI 10.3.1
#     Uninstalling pyobjc-framework-IntentsUI-10.3.1:
#       Successfully uninstalled pyobjc-framework-IntentsUI-10.3.1
#   Attempting uninstall: pyobjc-framework-InstantMessage
#     Found existing installation: pyobjc-framework-InstantMessage 10.3.1
#     Uninstalling pyobjc-framework-InstantMessage-10.3.1:
#       Successfully uninstalled pyobjc-framework-InstantMessage-10.3.1
#   Attempting uninstall: pyobjc-framework-GameKit
#     Found existing installation: pyobjc-framework-GameKit 10.3.1
#     Uninstalling pyobjc-framework-GameKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-GameKit-10.3.1
#   Attempting uninstall: pyobjc-framework-FileProviderUI
#     Found existing installation: pyobjc-framework-FileProviderUI 10.3.1
#     Uninstalling pyobjc-framework-FileProviderUI-10.3.1:
#       Successfully uninstalled pyobjc-framework-FileProviderUI-10.3.1
#   Attempting uninstall: pyobjc-framework-DiscRecordingUI
#     Found existing installation: pyobjc-framework-DiscRecordingUI 10.3.1
#     Uninstalling pyobjc-framework-DiscRecordingUI-10.3.1:
#       Successfully uninstalled pyobjc-framework-DiscRecordingUI-10.3.1
#   Attempting uninstall: pyobjc-framework-CoreText
#     Found existing installation: pyobjc-framework-CoreText 10.3.1
#     Uninstalling pyobjc-framework-CoreText-10.3.1:
#       Successfully uninstalled pyobjc-framework-CoreText-10.3.1
#   Attempting uninstall: pyobjc-framework-CoreServices
#     Found existing installation: pyobjc-framework-CoreServices 10.3.1
#     Uninstalling pyobjc-framework-CoreServices-10.3.1:
#       Successfully uninstalled pyobjc-framework-CoreServices-10.3.1
#   Attempting uninstall: pyobjc-framework-CoreAudioKit
#     Found existing installation: pyobjc-framework-CoreAudioKit 10.3.1
#     Uninstalling pyobjc-framework-CoreAudioKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-CoreAudioKit-10.3.1
#   Attempting uninstall: pyobjc-framework-ContactsUI
#     Found existing installation: pyobjc-framework-ContactsUI 10.3.1
#     Uninstalling pyobjc-framework-ContactsUI-10.3.1:
#       Successfully uninstalled pyobjc-framework-ContactsUI-10.3.1
#   Attempting uninstall: pyobjc-framework-CloudKit
#     Found existing installation: pyobjc-framework-CloudKit 10.3.1
#     Uninstalling pyobjc-framework-CloudKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-CloudKit-10.3.1
#   Attempting uninstall: pyobjc-framework-AVKit
#     Found existing installation: pyobjc-framework-AVKit 10.3.1
#     Uninstalling pyobjc-framework-AVKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-AVKit-10.3.1
#   Attempting uninstall: pyobjc-framework-AVFoundation
#     Found existing installation: pyobjc-framework-AVFoundation 10.3.1
#     Uninstalling pyobjc-framework-AVFoundation-10.3.1:
#       Successfully uninstalled pyobjc-framework-AVFoundation-10.3.1
#   Attempting uninstall: pyobjc-framework-ApplicationServices
#     Found existing installation: pyobjc-framework-ApplicationServices 10.3.1
#     Uninstalling pyobjc-framework-ApplicationServices-10.3.1:
#       Successfully uninstalled pyobjc-framework-ApplicationServices-10.3.1
#   Attempting uninstall: pyobjc-framework-Accessibility
#     Found existing installation: pyobjc-framework-Accessibility 10.3.1
#     Uninstalling pyobjc-framework-Accessibility-10.3.1:
#       Successfully uninstalled pyobjc-framework-Accessibility-10.3.1
#   Attempting uninstall: pyobjc-framework-SearchKit
#     Found existing installation: pyobjc-framework-SearchKit 10.3.1
#     Uninstalling pyobjc-framework-SearchKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-SearchKit-10.3.1
#   Attempting uninstall: pyobjc-framework-MetalPerformanceShadersGraph
#     Found existing installation: pyobjc-framework-MetalPerformanceShadersGraph 10.3.1
#     Uninstalling pyobjc-framework-MetalPerformanceShadersGraph-10.3.1:
#       Successfully uninstalled pyobjc-framework-MetalPerformanceShadersGraph-10.3.1
#   Attempting uninstall: pyobjc-framework-MediaPlayer
#     Found existing installation: pyobjc-framework-MediaPlayer 10.3.1
#     Uninstalling pyobjc-framework-MediaPlayer-10.3.1:
#       Successfully uninstalled pyobjc-framework-MediaPlayer-10.3.1
#   Attempting uninstall: pyobjc-framework-LocalAuthenticationEmbeddedUI
#     Found existing installation: pyobjc-framework-LocalAuthenticationEmbeddedUI 10.3.1
#     Uninstalling pyobjc-framework-LocalAuthenticationEmbeddedUI-10.3.1:
#       Successfully uninstalled pyobjc-framework-LocalAuthenticationEmbeddedUI-10.3.1
#   Attempting uninstall: pyobjc-framework-LaunchServices
#     Found existing installation: pyobjc-framework-LaunchServices 10.3.1
#     Uninstalling pyobjc-framework-LaunchServices-10.3.1:
#       Successfully uninstalled pyobjc-framework-LaunchServices-10.3.1
#   Attempting uninstall: pyobjc-framework-GameplayKit
#     Found existing installation: pyobjc-framework-GameplayKit 10.3.1
#     Uninstalling pyobjc-framework-GameplayKit-10.3.1:
#       Successfully uninstalled pyobjc-framework-GameplayKit-10.3.1
#   Attempting uninstall: pyobjc-framework-DictionaryServices
#     Found existing installation: pyobjc-framework-DictionaryServices 10.3.1
#     Uninstalling pyobjc-framework-DictionaryServices-10.3.1:
#       Successfully uninstalled pyobjc-framework-DictionaryServices-10.3.1
#   Attempting uninstall: pyobjc
#     Found existing installation: pyobjc 10.3.1
#     Uninstalling pyobjc-10.3.1:
#       Successfully uninstalled pyobjc-10.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# pyobjc-framework-iobluetooth 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-iobluetooth 10.3.1 requires pyobjc-framework-Cocoa>=10.3.1, but you have pyobjc-framework-cocoa 9.0.1 which is incompatible.
# pyobjc-framework-libxpc 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-libxpc 10.3.1 requires pyobjc-framework-Cocoa>=10.3.1, but you have pyobjc-framework-cocoa 9.0.1 which is incompatible.
# pyobjc-framework-symbols 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-symbols 10.3.1 requires pyobjc-framework-Cocoa>=10.3.1, but you have pyobjc-framework-cocoa 9.0.1 which is incompatible.
# pyobjc-framework-sensitivecontentanalysis 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-sensitivecontentanalysis 10.3.1 requires pyobjc-framework-Cocoa>=10.3.1, but you have pyobjc-framework-cocoa 9.0.1 which is incompatible.
# pyobjc-framework-sensitivecontentanalysis 10.3.1 requires pyobjc-framework-Quartz>=10.3.1, but you have pyobjc-framework-quartz 9.0.1 which is incompatible.
# pyobjc-framework-cinematic 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-cinematic 10.3.1 requires pyobjc-framework-AVFoundation>=10.3.1, but you have pyobjc-framework-avfoundation 9.0.1 which is incompatible.
# pyobjc-framework-cinematic 10.3.1 requires pyobjc-framework-Cocoa>=10.3.1, but you have pyobjc-framework-cocoa 9.0.1 which is incompatible.
# pyobjc-framework-cinematic 10.3.1 requires pyobjc-framework-CoreMedia>=10.3.1, but you have pyobjc-framework-coremedia 9.0.1 which is incompatible.
# pyobjc-framework-cinematic 10.3.1 requires pyobjc-framework-Metal>=10.3.1, but you have pyobjc-framework-metal 9.0.1 which is incompatible.
# pyobjc-framework-browserenginekit 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-browserenginekit 10.3.1 requires pyobjc-framework-Cocoa>=10.3.1, but you have pyobjc-framework-cocoa 9.0.1 which is incompatible.
# pyobjc-framework-browserenginekit 10.3.1 requires pyobjc-framework-CoreAudio>=10.3.1, but you have pyobjc-framework-coreaudio 9.0.1 which is incompatible.
# pyobjc-framework-browserenginekit 10.3.1 requires pyobjc-framework-CoreMedia>=10.3.1, but you have pyobjc-framework-coremedia 9.0.1 which is incompatible.
# pyobjc-framework-browserenginekit 10.3.1 requires pyobjc-framework-Quartz>=10.3.1, but you have pyobjc-framework-quartz 9.0.1 which is incompatible.
# pyobjc-framework-phase 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# pyobjc-framework-phase 10.3.1 requires pyobjc-framework-AVFoundation>=10.3.1, but you have pyobjc-framework-avfoundation 9.0.1 which is incompatible.
# pyobjc-framework-iobluetoothui 10.3.1 requires pyobjc-core>=10.3.1, but you have pyobjc-core 9.0.1 which is incompatible.
# Successfully installed py3-tts-3.5 pyobjc-9.0.1 pyobjc-core-9.0.1 pyobjc-framework-AVFoundation-9.0.1 pyobjc-framework-AVKit-9.0.1 pyobjc-framework-AVRouting-9.0.1 pyobjc-framework-Accessibility-9.0.1 pyobjc-framework-Accounts-9.0.1 pyobjc-framework-AdServices-9.0.1 pyobjc-framework-AdSupport-9.0.1 pyobjc-framework-AddressBook-9.0.1 pyobjc-framework-AppTrackingTransparency-9.0.1 pyobjc-framework-AppleScriptKit-9.0.1 pyobjc-framework-AppleScriptObjC-9.0.1 pyobjc-framework-ApplicationServices-9.0.1
 pyobjc-framework-MailKit-9.0.1 pyobjc-framework-MapKit-9.0.1 pyobjc-framework-MediaAccessibility-9.0.1 pyobjc-framework-MediaLibrary-9.0.1 pyobjc-framework-MediaPlayer-9.0.1 pyobjc-framework-MediaToolbox-9.0.1 pyobjc-framework-Metal-9.0.1 pyobjc-framework-MetalFX-9.0.1 pyobjc-framework-MetalKit-9.0.1 pyobjc-framework-MetalPerformanceShaders-9.0.1 pyobjc-framework-MetalPerformanceShadersGraph-9.0.1 pyobjc-framework-MetricKit-9.0.1 pyobjc-framework-ModelIO-9.0.1 pyobjc-framework-MultipeerConnectivity-9.0.1 pyobjc-framework-NaturalLanguage-9.0.1 pyobjc-framework-NetFS-9.0.1 pyobjc-framework-Network-9.0.1 pyobjc-framework-NetworkExtension-9.0.1 pyobjc-framework-NotificationCenter-9.0.1 pyobjc-framework-OSAKit-9.0.1 pyobjc-framework-OSLog-9.0.1 pyobjc-framework-OpenDirectory-9.0.1 pyobjc-framework-PassKit-9.0.1 pyobjc-framework-PencilKit-9.0.1 pyobjc-framework-Photos-9.0.1 pyobjc-framework-PhotosUI-9.0.1 pyobjc-framework-PreferencePanes-9.0.1 pyobjc-framework-PushKit-9.0.1 pyobjc-framework-Quartz-9.0.1 pyobjc ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.system("afplay audio.mp3")
# Out:
# Error: AudioQueueNew failed ('fmt?')
# 256

# %%
import speech_recognition as sr
# Function to transcribe speech from an audio file
def speech_to_text(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)
    
    try:
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        return "Speech recognition could not understand the audio"
    except sr.RequestError as e:
        return f"Could not request results from speech recognition service; {e}"
    
speech_to_text("audio.wav")
# Out:
# 'hey my name is Arnav and I work in a company called Cardinal hire this is a test message for opening hours whisper speech to text model'

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("I will speak this text")
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      10 def init(driverName: str = None, debug: bool = False) -> Engine:
#      11     """
#      12     Constructs a new TTS engine instance or reuses the existing instance for
#      13     the driver name.
#      14
#      15     @param driverName: Name of the platform specific driver to use. If
#      16         None, selects the default driver for the operating system.
#      17     @type: str
#      18     @param debug: Debugging output enabled or not
#      19     @type debug: bool
# ---> 20     @return: Engine instance
#      21     @rtype: L{engine.Engine}
#      22     """
#      23     try:
#
# File ~/anaconda3/lib/python3.11/weakref.py:136, in WeakValueDictionary.__getitem__(self, key)
#     135     self._commit_removals()
# --> 136 o = self.data[key]()
#     137 if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# error                                     Traceback (most recent call last)
# Cell In[46], line 2
#       1 import pyttsx3
# ----> 2 engine = pyttsx3.init()
#       3 engine.say("I will speak this text")
#       4 engine.runAndWait()
#
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/__init__.py:22, in init(driverName, debug)
#      20     eng = _activeEngines[driverName]
#      21 except KeyError:
# ---> 22     eng = Engine(driverName, debug)
#      23     _activeEngines[driverName] = eng
#      24 return eng
#
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/engine.py:30, in Engine.__init__(self, driverName, debug)
#      20 def __init__(self, driverName=None, debug=False):
#      21     """
#      22     Constructs a new TTS engine instance.
#      23
#    (...)
#      28     @type debug: bool
#      29     """
# ---> 30     self.proxy = driver.DriverProxy(weakref.proxy(self), driverName, debug)
#      31     # initialize other vars
#      32     self._connects = {}
#
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/driver.py:50, in DriverProxy.__init__(self, engine, driverName, debug)
#      48 # import driver module
#      49 name = 'pyttsx3.drivers.%s' % driverName
# ---> 50 self._module = importlib.import_module(name)
#      51 # build driver instance
#      52 self._driver = self._module.buildDriver(weakref.proxy(self))
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/drivers/nsss.py:12
#       8 from ..voice import Voice
#      11 # noinspection PyUnresolvedReferences
# ---> 12 class RunLoopStopper(PyObjCAppHelperRunLoopStopper):
#      13     """
#      14     Overrides PyObjCAppHelperRunLoopStopper to terminate after endLoop.
#      15     """
#      17     def __init__(self):
#
# error: RunLoopStopper is overriding existing Objective-C class

# %%
import pyttsx3
engine = pyttsx3.init("dummy") # object creation

""" RATE"""
rate = engine.getProperty('rate')   # getting details of current speaking rate
print (rate)                        #printing current voice rate
engine.setProperty('rate', 125)     # setting up new voice rate


"""VOLUME"""
volume = engine.getProperty('volume')   #getting to know current volume level (min=0 and max=1)
print (volume)                          #printing current volume level
engine.setProperty('volume',1.0)    # setting up volume level  between 0 and 1

"""VOICE"""
voices = engine.getProperty('voices')       #getting details of current voice
#engine.setProperty('voice', voices[0].id)  #changing index, changes voices. o for male
engine.setProperty('voice', voices[1].id)   #changing index, changes voices. 1 for female

engine.say("Hello World!")
engine.say('My current speaking rate is ' + str(rate))
engine.runAndWait()
engine.stop()

"""Saving Voice to a file"""
# On linux make sure that 'espeak' and 'ffmpeg' are installed
engine.save_to_file('Hello World', 'test.mp3')
engine.runAndWait()
# Out:
# 125
# 1.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 27
#      25 """Saving Voice to a file"""
#      26 # On linux make sure that 'espeak' and 'ffmpeg' are installed
# ---> 27 engine.save_to_file('Hello World', 'test.mp3')
#      28 engine.runAndWait()
#
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/engine.py:119, in Engine.save_to_file(self, text, filename, name)
#     108 def save_to_file(self, text, filename, name=None):
#     109     '''
#     110     Adds an utterance to speak to the event queue.
#     111
#    (...)
#     117     @type name: str
#     118     '''
# --> 119     self.proxy.save_to_file(text, filename, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pyttsx3/driver.py:162, in DriverProxy.save_to_file(self, text, filename, name)
#     153 def save_to_file(self, text, filename, name):
#     154     '''
#     155     Called by the engine to push a say command onto the queue.
#     156
#    (...)
#     160     @type name: str
#     161     '''
# --> 162     self._push(self._driver.save_to_file, (text, filename), name)
#
# AttributeError: 'DummyDriver' object has no attribute 'save_to_file'

# %%
import openai
import os
openai.api_key = "sk-1W6914esN5qg0ZwDySKMdxcf2LkDr-gPym4CpTATv1T3BlbkFJw05DMfogYmZGuHrMqc1dPJV1CbZPZQ_J8AlrX2oxMA"
import wave

class Config:
    channels = 2
    sample_width = 2
    sample_rate = 44100

def save_wav_file(file_path, wav_bytes):
    with wave.open(file_path, 'wb') as wav_file:
        wav_file.setnchannels(Config.channels)
        wav_file.setsampwidth(Config.sample_width)
        wav_file.setframerate(Config.sample_rate)
        wav_file.writeframes(wav_bytes)

def transcribe(file_path):
    audio_file = open(file_path, 'rb')
    transcription = openai.Audio.transcribe("whisper-1", audio_file)
    return transcription['text']

transcribe("audio.wav")
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[55], line 23
#      20     transcription = openai.Audio.transcribe("whisper-1", audio_file)
#      21     return transcription['text']
# ---> 23 transcribe("audio.wav")
#
# Cell In[55], line 20, in transcribe(file_path)
#      18 def transcribe(file_path):
#      19     audio_file = open(file_path, 'rb')
# ---> 20     transcription = openai.Audio.transcribe("whisper-1", audio_file)
#      21     return transcription['text']
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Audio, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
from gtts import gTTS
tts = gTTS('hello')
tts.
tts.save('hello.mp3')

# %%
#pip install google-cloud-speech
#pip install pyttsx3
#pip install moviepy
#pip install ffmpeg exe
#pip install opencv-python
#pip install anthropic
#pip install SpeechRecognition
#pip install pyaudio
# pip install numpy
# pip install setuptools
# pip install anthropic
# pip install gtts
# pip install ipython google-cloud-texttospeech
# pip install streamlit
# pip install streamlit_option_menu
# pip install app-utils
# pip install Pillow
# pip install streamlit_extras
# pip install streamlit_lottie
# pip install langchain
# pip install langchain-community
# pip install audio-recorder-streamlit
# pip install boto3
# pip install tiktoken
# pip install faiss-cpu
# pip install pydub
# pip install av
# pip install twilio
# pip install streamlit_webrtc
# pip install ffmpeg-python
# pip install openai-whisper
# Out:
#   Cell In[28], line 8
#     pip install anthropic
#         ^
# SyntaxError: invalid syntax

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("audio.mp3")
print(result["text"])
# Out:
# /Users/arnavgarg/anaconda3/lib/python3.11/site-packages/whisper/__init__.py:146: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /Users/arnavgarg/anaconda3/lib/python3.11/site-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 4
#       1 import whisper
#       3 model = whisper.load_model("base")
# ----> 4 result = model.transcribe("audio.mp3")
#       5 print(result["text"])
#
# File ~/anaconda3/lib/python3.11/site-packages/whisper/transcribe.py:122, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, **decode_options)
#     119     decode_options["fp16"] = False
#     121 # Pad 30-seconds of silence to the input audio, for slicing
# --> 122 mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
#     123 content_frames = mel.shape[-1] - N_FRAMES
#     125 if decode_options.get("language", None) is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/whisper/audio.py:140, in log_mel_spectrogram(audio, n_mels, padding, device)
#     138 if not torch.is_tensor(audio):
#     139     if isinstance(audio, str):
# --> 140         audio = load_audio(audio)
#     141     audio = torch.from_numpy(audio)
#     143 if device is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/whisper/audio.py:58, in load_audio(file, sr)
#      56 # fmt: on
#      57 try:
# ---> 58     out = run(cmd, capture_output=True, check=True).stdout
#      59 except CalledProcessError as e:
#      60     raise RuntimeError(f"Failed to load audio: {e.stderr.decode()}") from e
#
# File ~/anaconda3/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1950, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1948     if errno_num != 0:
#    1949         err_msg = os.strerror(errno_num)
# -> 1950     raise child_exception_type(errno_num, err_msg, err_filename)
#    1951 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ffmpeg'

# %%
import cv2
import streamlit as st
import numpy as np
import tempfile

cap = cv2.VideoCapture(1)
st.title("Webcam Live Feed")
frame_placeholder = st.empty()
stop_button = st.button("Stop")
# Out:
# 2024-08-02 12:35:38.935 python[36274:2833367] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 2024-08-02 12:35:40.492
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/arnavgarg/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
import anthropic

client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)

message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=1000,
    temperature=0,
    system="You are a master coding assistant. Respond with Python solution to the problem.",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "How to reverse a list in Python?"
                }
            ]
        }
    ]
)
print(message.content[0].text)
# Out:
# There are several ways to reverse a list in Python. Here are three common methods:
#
# 1. Using the built-in `reverse()` method:
#
# ```python
# def reverse_list(lst):
#     lst.reverse()
#     return lst
#
# # Example usage
# my_list = [1, 2, 3, 4, 5]
# reversed_list = reverse_list(my_list)
# print(reversed_list)  # Output: [5, 4, 3, 2, 1]
# ```
#
# 2. Using slicing with a step of -1:
#
# ```python
# def reverse_list(lst):
#     return lst[::-1]
#
# # Example usage
# my_list = [1, 2, 3, 4, 5]
# reversed_list = reverse_list(my_list)
# print(reversed_list)  # Output: [5, 4, 3, 2, 1]
# ```
#
# 3. Using a loop to reverse the list in-place:
#
# ```python
# def reverse_list(lst):
#     left = 0
#     right = len(lst) - 1
#     while left < right:
#         lst[left], lst[right] = lst[right], lst[left]
#         left += 1
#         right -= 1
#     return lst
#
# # Example usage
# my_list = [1, 2, 3, 4, 5]
# reversed_list = reverse_list(my_list)
# print(reversed_list)  # Output: [5, 4, 3, 2, 1]
# ```
#
# All these methods will reverse the list. The first two methods create a new reversed list, while the third method modifies the original list in-place. Choose the one that best fits your needs.
#
# Note that if you just need to iterate over a list in reverse order without actually modifying it, you can use the `reversed()` function:
#
# ```python
# my_list = [1, 2, 3, 4, 5]
# for item in reversed(my_list):
#     print(item)
# ```
#
# This will print the items in reverse order without changing the original list.

# %%
import speech_recognition as sr
import pyaudio
import wave

def get_input_device_info():
    audio = pyaudio.PyAudio()
    for i in range(audio.get_device_count()):
        info = audio.get_device_info_by_index(i)
        print(f"Device {i}: {info['name']} - {info['maxInputChannels']} input channels")
    audio.terminate()

def record_audio(duration=5, sample_rate=44100, chunk=1024, channels=1):
    audio = pyaudio.PyAudio()
    try:
        stream = audio.open(format=pyaudio.paInt16,
                            channels=channels,
                            rate=sample_rate,
                            input=True,
                            frames_per_buffer=chunk)
    except OSError as e:
        audio.terminate()
        raise RuntimeError(f"Could not open audio stream: {e}")
    
    print("Recording...")
    frames = []

    try:
        for _ in range(0, int(sample_rate / chunk * duration)):
            data = stream.read(chunk)
            frames.append(data)
    except Exception as e:
        stream.stop_stream()
        stream.close()
        audio.terminate()
        raise RuntimeError(f"Error during recording: {e}")

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return frames, sample_rate

def save_audio(frames, sample_rate, filename="output.wav"):
    wf = wave.open(filename, 'wb')
    wf.setnchannels(1)  # Ensure it matches the recording channel
    wf.setsampwidth(pyaudio.PyAudio().get_sample_size(pyaudio.paInt16))
    wf.setframerate(sample_rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def speech_to_text(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)
    
    try:
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        return "Speech recognition could not understand the audio"
    except sr.RequestError as e:
        return f"Could not request results from speech recognition service; {e}"

# Main execution
get_input_device_info()  # Check available input devices and their properties

duration = 5  # Record for 5 seconds
frames, sample_rate = record_audio(duration, channels=1)  # Set channels to 1
save_audio(frames, sample_rate)

text = speech_to_text("output.wav")
print("Transcribed text:", text)
# Out:
# Device 0: MacBook Pro Microphone - 1 input channels
# Device 1: MacBook Pro Speakers - 0 input channels
# Device 2: Iverson Microphone - 1 input channels
# Device 3: Microsoft Teams Audio - 2 input channels
# Recording...
# Finished recording.
# I0000 00:00:1722570860.639528 25660272 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio

# %%
import numpy as np
import cv2 as cv
 
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
 # Capture frame-by-frame
 ret, frame = cap.read()
 
 # if frame is read correctly ret is True
 if not ret:
    print("Can't receive frame (stream end?). Exiting ...")
    break
 # Our operations on the frame come here
 gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
 # Display the resulting frame
 cv.imshow('frame', gray)
 if cv.waitKey(1) == ord('q'):
    break
 
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# # Question Generation

# %%
# Import the necessary libraries

import cv2
import numpy as np

# Load the Job Description

with open('job_description.txt', 'r') as file:
    job_description = file.read()

# Load the Resume

with open('resume.txt', 'r') as file:
    resume = file.read()

# Create a function to generate a custom questionnaire

def generate_questionnaire(job_description, resume):
    # Create a list to store the questions
    questions = []
    
    return questions

# %%
#questions = generate_questionnaire(job_description, resume)

# Questions for MVP Recruiter Screen
questions = [ 
             # Instructions
             "I am going to ask you a few questions to better understand your background and experience. \
             Please answer honestly and to the best of your ability. \
             There are no right or wrong answers, we are just trying to get to know you better. \
             When your answer has ended, please say the statement 'My answer has ended'. \
             Are you ready to begin?",

             # Pleasantries
             "Hi! How are you doing today?", 
             "What is your name?", 

             # Qualifying the candidate
             "What is your expected annual salary range for this role?", 
             "What is your current work or employment authorisation?",
             "Are you able to work on-site 3 days a week?",

             # Custom Questions for Job Description: Customized by the Account Manager
             "What is your ICP",
             "Base salary for this role is fixed at $70000, will that work for you? If not, would you withdraw your application for this role?",
             "Do you have experience with technical-SaaS based companies?",

             # Technical Interview
             "What is your experience in audio processing?",
             "What is your experience in image processing?",
             "What is your experience in data analysis?",
             "What is your experience in data visualization?"
             ]

# %%
from typing import Sequence

import google.cloud.texttospeech as tts


def unique_languages_from_voices(voices: Sequence[tts.Voice]):
    language_set = set()
    for voice in voices:
        for language_code in voice.language_codes:
            language_set.add(language_code)
    return language_set


def list_languages():
    client = tts.TextToSpeechClient(credentials = GOOGLE_API_KEY)
    response = client.list_voices()
    languages = unique_languages_from_voices(response.voices)

    print(f" Languages: {len(languages)} ".center(60, "-"))
    for i, language in enumerate(sorted(languages)):
        print(f"{language:>10}", end="\n" if i % 5 == 4 else "")

# %%
list_languages()
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_channel.py:1181, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1175 (
#    1176     state,
#    1177     call,
#    1178 ) = self._blocking(
#    1179     request, timeout, metadata, credentials, wait_for_ready, compression
#    1180 )
# -> 1181 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "Getting metadata from plugin failed with error: 'str' object has no attribute 'before_request'"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Getting metadata from plugin failed with error: \'str\' object has no attribute \'before_request\'", grpc_status:14, created_time:"2024-08-01T23:33:36.76031-07:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 list_languages()
#
# Cell In[18], line 16, in list_languages()
#      14 def list_languages():
#      15     client = tts.TextToSpeechClient(credentials = GOOGLE_API_KEY)
# ---> 16     response = client.list_voices()
#      17     languages = unique_languages_from_voices(response.voices)
#      19     print(f" Languages: {len(languages)} ".center(60, "-"))
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/texttospeech_v1/services/text_to_speech/client.py:772, in TextToSpeechClient.list_voices(self, request, language_code, retry, timeout, metadata)
#     769 self._validate_universe_domain()
#     771 # Send the request.
# --> 772 response = rpc(
#     773     request,
#     774     retry=retry,
#     775     timeout=timeout,
#     776     metadata=metadata,
#     777 )
#     779 # Done; return the response.
#     780 return response
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ServiceUnavailable: 503 Getting metadata from plugin failed with error: 'str' object has no attribute 'before_request'

# %%
# write code to convert the questions to audio using Google Text-to-Speech API

from gtts import gTTS
import os

for i, question in enumerate(questions):
    tts = gTTS(text=question, lang='en')
    tts.save(f'question_{i}.mp3')
# Out:
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found
# sh: start: command not found

# %% [markdown]
# # Interviewing

# %%
# Inputting the video file and reading it in different formats

cap = cv2.VideoCapture('video.mp4') # Reading the video file

# Reading the video file frame by frame

while cap.isOpened(): # Checking if the video file is opened
    ret, frame = cap.read() # Reading the video file frame by frame, ret is a boolean value that returns true if the frame is available, frame is the image array
    if not ret: # If the frame is not available
        print("Can't receive frame (stream end?). Exiting ...")
        break
    cv2.imshow('AI Interviewer', frame) # Displaying the frame
    if cv2.waitKey(1) & 0XFF == ord('q'): # If the user presses 'q' key
        cap.release() # Releasing the video file
        cv2.destroyAllWindows() # Closing all the windows
        break
# Out:
# OpenCV: Couldn't read video stream from file "video.mp4"

# %%
import cv2
import threading
import speech_recognition as sr
import pyaudio
import wave
from google.cloud import speech_v1p1beta1 as speech
from google.oauth2 import service_account

# Initialize the recognizer
recognizer = sr.Recognizer()

# Set up the Google Cloud Speech client
client = speech.SpeechClient(credentials=GOOGLE_API_KEY)

# Function to get input device information
def get_input_device_info():
    audio = pyaudio.PyAudio()
    for i in range(audio.get_device_count()):
        info = audio.get_device_info_by_index(i)
        print(f"Device {i}: {info['name']} - {info['maxInputChannels']} input channels")
    audio.terminate()

# Function to record audio
def record_audio(frames, sample_rate=44100, chunk=1024, channels=1):
    audio = pyaudio.PyAudio()
    try:
        stream = audio.open(format=pyaudio.paInt16,
                            channels=channels,
                            rate=sample_rate,
                            input=True,
                            frames_per_buffer=chunk)
    except OSError as e:
        audio.terminate()
        raise RuntimeError(f"Could not open audio stream: {e}")
    
    print("Recording audio...")
    try:
        while not stop_event.is_set():
            data = stream.read(chunk)
            frames.append(data)
    except Exception as e:
        stream.stop_stream()
        stream.close()
        audio.terminate()
        raise RuntimeError(f"Error during recording: {e}")

    print("Finished recording audio.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

# Function to save recorded audio to a file
def save_audio(frames, sample_rate, filename="output.wav"):
    wf = wave.open(filename, 'wb')
    wf.setnchannels(1)  # Ensure it matches the recording channel
    wf.setsampwidth(pyaudio.PyAudio().get_sample_size(pyaudio.paInt16))
    wf.setframerate(sample_rate)
    wf.writeframes(b''.join(frames))
    wf.close()

# Function to transcribe speech from an audio file
def speech_to_text(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)
    
    try:
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        return "Speech recognition could not understand the audio"
    except sr.RequestError as e:
        return f"Could not request results from speech recognition service; {e}"

# Function to handle video capture
def capture_video():
    cap = cv2.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        cv2.imshow('Live Video', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            stop_event.set()  # Signal the audio recording thread to stop
            break
    cap.release()
    cv2.destroyAllWindows()

# Main execution
get_input_device_info()  # Check available input devices and their properties

# Record for the length of the video
frames = []
stop_event = threading.Event()
audio_thread = threading.Thread(target=record_audio, args=(frames,))
audio_thread.start()

capture_video()  # Start capturing video

audio_thread.join()  # Wait for the audio recording to finish
save_audio(frames, 44100)  # Save the recorded audio

text = speech_to_text("output.wav")
print("Transcribed text:", text)
# Out:
# I0000 00:00:1722570879.493673 25660272 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# Device 0: MacBook Pro Microphone - 1 input channels
# Device 1: MacBook Pro Speakers - 0 input channels
# Device 2: Iverson Microphone - 1 input channels
# Device 3: Microsoft Teams Audio - 2 input channels
# Recording audio...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 99
#      96 audio_thread = threading.Thread(target=record_audio, args=(frames,))
#      97 audio_thread.start()
# ---> 99 capture_video()  # Start capturing video
#     101 audio_thread.join()  # Wait for the audio recording to finish
#     102 save_audio(frames, 44100)  # Save the recorded audio
#
# Cell In[41], line 84, in capture_video()
#      82     break
#      83 cv2.imshow('Live Video', frame)
# ---> 84 if cv2.waitKey(1) & 0xFF == ord('q'):
#      85     stop_event.set()  # Signal the audio recording thread to stop
#      86     break
#
# KeyboardInterrupt:

# %%
# This is the 3 second live transcription

# %%
import cv2
import threading
import speech_recognition as sr
import pyaudio
import wave
import time

# Initialize the recognizer
recognizer = sr.Recognizer()

# Function to get input device information
def get_input_device_info():
    audio = pyaudio.PyAudio()
    for i in range(audio.get_device_count()):
        info = audio.get_device_info_by_index(i)
        print(f"Device {i}: {info['name']} - {info['maxInputChannels']} input channels")
    audio.terminate()

# Function to record audio
def record_audio(frames, sample_rate=44100, chunk=4096, channels=1, duration=1):
    audio = pyaudio.PyAudio()
    try:
        stream = audio.open(format=pyaudio.paInt16,
                            channels=channels,
                            rate=sample_rate,
                            input=True,
                            frames_per_buffer=chunk)
    except OSError as e:
        audio.terminate()
        raise RuntimeError(f"Could not open audio stream: {e}")
    
    print("Recording audio...")
    try:
        while not stop_event.is_set():
            start_time = time.time()
            chunk_frames = []
            while time.time() - start_time < duration:
                try:
                    data = stream.read(chunk, exception_on_overflow=False)
                    chunk_frames.append(data)
                except IOError as e:
                    print(f"Error recording: {e}")
                    continue
                if stop_event.is_set():
                    break
            frames.append(b''.join(chunk_frames))
            threading.Thread(target=save_and_transcribe, args=(chunk_frames, sample_rate)).start()
    except Exception as e:
        stream.stop_stream()
        stream.close()
        audio.terminate()
        raise RuntimeError(f"Error during recording: {e}")

    print("Finished recording audio.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

# Function to save and transcribe audio chunk
def save_and_transcribe(frames, sample_rate, filename="output_chunk.wav"):
    wf = wave.open(filename, 'wb')
    wf.setnchannels(1)
    wf.setsampwidth(pyaudio.PyAudio().get_sample_size(pyaudio.paInt16))
    wf.setframerate(sample_rate)
    wf.writeframes(b''.join(frames))
    wf.close()
    
    text = speech_to_text(filename)
    print("Transcribed text:", text)

# Function to transcribe speech from an audio file
def speech_to_text(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)
    
    try:
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        return "Speech recognition could not understand the audio"
    except sr.RequestError as e:
        return f"Could not request results from speech recognition service; {e}"

# Function to handle video capture
def capture_video():
    cap = cv2.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        cv2.imshow('Live Video', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            stop_event.set()  # Signal the audio recording thread to stop
            break
    cap.release()
    cv2.destroyAllWindows()

# Main execution
get_input_device_info()  # Check available input devices and their properties

# Record for the length of the video
frames = []
stop_event = threading.Event()
audio_thread = threading.Thread(target=record_audio, args=(frames,))
audio_thread.start()

capture_video()  # Start capturing video

audio_thread.join()  # Wait for the audio recording to finish
# Out:
# Device 0: MacBook Pro Microphone - 1 input channels
# Device 1: MacBook Pro Speakers - 0 input channels
# Device 2: Iverson Microphone - 1 input channels
# Device 3: Microsoft Teams Audio - 2 input channels
# Recording audio...
# I0000 00:00:1722571053.183337 30584007 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571054.207414 30584066 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571055.230564 30584111 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571056.255889 30584156 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571057.280753 30584199 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: much faster
# I0000 00:00:1722571058.304335 30584237 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# I0000 00:00:1722571059.325329 30584282 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: most of
# I0000 00:00:1722571060.348874 30584327 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: this is going to be
# Transcribed text: which recognition
# I0000 00:00:1722571061.372979 30584375 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: do not understand
# I0000 00:00:1722571062.400998 30584417 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571063.423790 30584457 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571064.443837 30584495 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571065.468312 30584536 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571066.493297 30584583 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: better
# I0000 00:00:1722571067.516390 30584623 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: what's 305
# I0000 00:00:1722571068.542707 30584701 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571069.564490 30584746 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: play broken
# I0000 00:00:1722571070.590914 30584799 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: full
# I0000 00:00:1722571071.612519 30584842 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571072.636121 30584883 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571073.663286 30584920 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: play Netflix
# I0000 00:00:1722571074.688475 30584958 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571075.711537 30585008 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571076.733793 30585047 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# I0000 00:00:1722571077.759867 30585086 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio
# Finished recording audio.
# I0000 00:00:1722571078.781621 30585133 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# Transcribed text: Speech recognition could not understand the audio

# %%
# Extract audio from computer vision video

import moviepy.editor as mp

video = mp.VideoFileClip("video.mp4")
audio = video.audio
audio.write_audiofile("audio.mp3")

# Import the necessary libraries

import speech_recognition as sr

# Create a function to convert speech to text

def speech_to_text(audio_file):
    recognizer = sr.Recognizer() # Creating a recognizer object
    with sr.AudioFile(audio_file) as source: # Opening the audio file
        audio = recognizer.record(source) # Recording the audio
    try:
        text = recognizer.recognize_google(audio) # Recognizing the audio using Google Speech Recognition
        return text # Returning the text
    except sr.UnknownValueError: # If the audio is not recognized
        return "Speech recognition could not understand the audio"
    except sr.RequestError as e: # If there is an error in the request
        return f"Could not request results from speech recognition service; {e}"
    
# Convert speech to text

text = speech_to_text("audio.mp3")

# Print the transcribed text
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Extract audio from computer vision video
# ----> 3 import moviepy.editor as mp
#       5 video = mp.VideoFileClip("video.mp4")
#       6 audio = video.audio
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/editor.py:36
#      33 os.environ['PYGAME_HIDE_SUPPORT_PROMPT'] = "1"
#      35 # Clips
# ---> 36 from .video.io.VideoFileClip import VideoFileClip
#      37 from .video.io.ImageSequenceClip import ImageSequenceClip
#      38 from .video.io.downloader import download_webfile
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/video/io/VideoFileClip.py:3
#       1 import os
# ----> 3 from moviepy.audio.io.AudioFileClip import AudioFileClip
#       4 from moviepy.Clip import Clip
#       5 from moviepy.video.io.ffmpeg_reader import FFMPEG_VideoReader
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/audio/io/AudioFileClip.py:3
#       1 from __future__ import division
# ----> 3 from moviepy.audio.AudioClip import AudioClip
#       4 from moviepy.audio.io.readers import FFMPEG_AudioReader
#       7 class AudioFileClip(AudioClip):
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/audio/AudioClip.py:7
#       4 import proglog
#       5 from tqdm import tqdm
# ----> 7 from moviepy.audio.io.ffmpeg_audiowriter import ffmpeg_audiowrite
#       8 from moviepy.Clip import Clip
#       9 from moviepy.decorators import requires_duration
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/audio/io/ffmpeg_audiowriter.py:7
#       4 import proglog
#       6 from moviepy.compat import DEVNULL
# ----> 7 from moviepy.config import get_setting
#       8 from moviepy.decorators import requires_duration
#      11 class FFMPEG_AudioWriter:
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/config.py:36
#      34 if FFMPEG_BINARY=='ffmpeg-imageio':
#      35     from imageio.plugins.ffmpeg import get_exe
# ---> 36     FFMPEG_BINARY = get_exe()
#      38 elif FFMPEG_BINARY=='auto-detect':
#      40     if try_cmd(['ffmpeg'])[0]:
#
# File ~/anaconda3/lib/python3.11/site-packages/imageio/plugins/ffmpeg.py:173, in get_exe()
#     170 def get_exe():  # pragma: no cover
#     171     """Wrapper for imageio_ffmpeg.get_ffmpeg_exe()"""
# --> 173     return imageio_ffmpeg.get_ffmpeg_exe()
#
# File ~/anaconda3/lib/python3.11/site-packages/imageio_ffmpeg/_utils.py:33, in get_ffmpeg_exe()
#      30     return exe
#      32 # Nothing was found
# ---> 33 raise RuntimeError(
#      34     "No ffmpeg exe could be found. Install ffmpeg on your system, "
#      35     "or set the IMAGEIO_FFMPEG_EXE environment variable."
#      36 )
#
# RuntimeError: No ffmpeg exe could be found. Install ffmpeg on your system, or set the IMAGEIO_FFMPEG_EXE environment variable.

# %%
# Define speech to text function

def speech_to_text(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)
    
    try:
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        return "Speech recognition could not understand the audio"
    except sr.RequestError as e:
        return f"Could not request results from speech recognition service; {e}"

# %%
# Define function to get response from LLM

def get_response(text, conversation):
    conversation.append({"role": "user", "content": [{"type": "text", "text": text}]})
    message = client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1000,
        temperature=0,
        system="You are a master coding assistant. Respond with Python solution to the problem.",
        messages = conversation
    )
    return message.content

# %%
# Define text to speech function

def text_to_speech(text, filename="output.wav"):
    tts = gTTS(text)
    tts.save(filename)

# %%
# Define function to play audio

def play_audio(filename="output.wav"):
    playsound(filename)

# %%
# Main execution

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame', gray)
    if cv2.waitKey(1) == ord('q'):
        break

    # Save the frame as an image
    cv2.imwrite('frame.jpg', frame)

    # Convert the image to text
    text = ocr_image('frame.jpg')

    # Get response from LLM
    response = get_response(text)

    # Convert the response to speech
    text_to_speech(response)

    # Play the audio
    play_audio()

# %% [markdown]
# # Question Grading

# %%
def grading(question, answer):
